# %% [markdown]
# <a href="https://colab.research.google.com/github/alurabhinava/IITM_BS_in_DataScience/blob/MachineLearningPractice/MLP_Week1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# prompt: hello world documentation

"""
This is a simple Python program that prints "Hello, world!".

This program can be used as an example of how to write a simple Python program.
It can also be used to test your Python installation.

To run this program, simply save it as a file with a .py extension (e.g., hello_world.py) and then run it from the command line:

python hello_world.py

This will print the following output to the console:

Hello, world!
"""

print("Hello, world!")
# Out:
# Hello, world!

# %% [markdown]
# # prompt: Document Introduction to Pandas
#
# """
# # Introduction to Pandas
#
# Pandas is a powerful Python library used for data manipulation and analysis. It provides easy-to-use data structures and operations for manipulating numerical tables and time series.
#
# ## Key Features of Pandas
#
# * **Data Structures:**
#     * DataFrame: A two-dimensional, tabular data structure with labeled axes (rows and columns).
#     * Series: A one-dimensional array with an associated index.
#
# * **Data Manipulation:**
#     * Data selection and filtering
#     * Data transformation
#     * Data aggregation
#     * Data merging and joining
#
# * **Data Analysis:**
#     * Descriptive statistics
#     * Time series analysis
#     * Machine learning
#
# ## Getting Started with Pandas
#
# To use Pandas, you first need to import it into your Python script:
#
# ### Why Use Pandas?
#
# * **Data Manipulation:** Pandas offers a variety of tools for manipulating data, including:
#     * Selecting and filtering data
#     * Adding, removing, and modifying columns
#     * Merging and joining data sets
#     * Grouping and summarizing data
# * **Data Analysis:** Pandas provides a rich set of statistical methods for analyzing data, including:
#     * Descriptive statistics (e.g., mean, median, standard deviation)
#     * Correlation analysis
#     * Regression analysis
#     * Time series analysis
# * **Data Visualization:** Pandas integrates seamlessly with matplotlib, allowing you to create informative and visually appealing data visualizations.
#
# ### Getting Started with Pandas
#
# To get started with Pandas, you can install it using pip:
#
# ### Key Features of Pandas:
#
# * **Data Structures:**
#     * DataFrame: A tabular data structure with rows and columns.
#     * Series: A one-dimensional array-like object containing a sequence of values.
#
# * **Data Manipulation:**
#     * Data cleaning and wrangling.
#     * Data transformation and aggregation.
#     * Data merging and joining.
#
# * **Data Analysis:**
#     * Statistical analysis and computation.
#     * Time series analysis.
#     * Data visualization.
#
# ### Getting Started with Pandas:
#
# 1. **Installation:** Install Pandas using pip:

# %%
import pandas as pd
pd.__version__
# Out:
# '2.0.3'

# %%
from sklearn.datasets import load_diabetes
diabetes = load_diabetes(as_frame=True)
print(type(diabetes['data']))
# Out:
# <class 'pandas.core.frame.DataFrame'>

# %%
print(diabetes.DESCR)
# Out:
# .. _diabetes_dataset:
#
# Diabetes dataset
# ----------------
#
# Ten baseline variables, age, sex, body mass index, average blood
# pressure, and six blood serum measurements were obtained for each of n =
# 442 diabetes patients, as well as the response of interest, a
# quantitative measure of disease progression one year after baseline.
#
# **Data Set Characteristics:**
#
#   :Number of Instances: 442
#
#   :Number of Attributes: First 10 columns are numeric predictive values
#
#   :Target: Column 11 is a quantitative measure of disease progression one year after baseline
#
#   :Attribute Information:
#       - age     age in years
#       - sex
#       - bmi     body mass index
#       - bp      average blood pressure
#       - s1      tc, total serum cholesterol
#       - s2      ldl, low-density lipoproteins
#       - s3      hdl, high-density lipoproteins
#       - s4      tch, total cholesterol / HDL
#       - s5      ltg, possibly log of serum triglycerides level
# ...

# %%
df = diabetes['data']

# %% [markdown]
# ## Creating pandas dataframe from series

# %%
cities = pd.Series(['Mumbai', 'Bangalore', 'Chennai'])
population = pd.Series([17000000, 13000000, 6000000])

# %%
city_info_df = pd.DataFrame({'City': cities, 'Population': population})

# %%
city_info_df
# Out:
#         City  Population
# 0     Mumbai    17000000
# 1  Bangalore    13000000
# 2    Chennai     6000000

# %%
df.head()
# Out:
#         age       sex       bmi        bp        s1        s2        s3  \
# 0  0.038076  0.050680  0.061696  0.021872 -0.044223 -0.034821 -0.043401
# 1 -0.001882 -0.044642 -0.051474 -0.026328 -0.008449 -0.019163  0.074412
# 2  0.085299  0.050680  0.044451 -0.005670 -0.045599 -0.034194 -0.032356
# 3 -0.089063 -0.044642 -0.011595 -0.036656  0.012191  0.024991 -0.036038
# 4  0.005383 -0.044642 -0.036385  0.021872  0.003935  0.015596  0.008142
#
#          s4        s5        s6
# 0 -0.002592  0.019907 -0.017646
# 1 -0.039493 -0.068332 -0.092204
# 2 -0.002592  0.002861 -0.025930
# 3  0.034309  0.022688 -0.009362
# 4 -0.002592 -0.031988 -0.046641

# %%
df.tail()
# Out:
#           age       sex       bmi        bp        s1        s2        s3  \
# 437  0.041708  0.050680  0.019662  0.059744 -0.005697 -0.002566 -0.028674
# 438 -0.005515  0.050680 -0.015906 -0.067642  0.049341  0.079165 -0.028674
# 439  0.041708  0.050680 -0.015906  0.017293 -0.037344 -0.013840 -0.024993
# 440 -0.045472 -0.044642  0.039062  0.001215  0.016318  0.015283 -0.028674
# 441 -0.045472 -0.044642 -0.073030 -0.081413  0.083740  0.027809  0.173816
#
#            s4        s5        s6
# 437 -0.002592  0.031193  0.007207
# 438  0.034309 -0.018114  0.044485
# 439 -0.011080 -0.046883  0.015491
# 440  0.026560  0.044529 -0.025930
# 441 -0.039493 -0.004222  0.003064

# %%
df.columns
# Out:
# Index(['age', 'sex', 'bmi', 'bp', 's1', 's2', 's3', 's4', 's5', 's6'], dtype='object')

# %%
df.describe()
# Out:
#                 age           sex           bmi            bp            s1  \
# count  4.420000e+02  4.420000e+02  4.420000e+02  4.420000e+02  4.420000e+02
# mean  -2.511817e-19  1.230790e-17 -2.245564e-16 -4.797570e-17 -1.381499e-17
# std    4.761905e-02  4.761905e-02  4.761905e-02  4.761905e-02  4.761905e-02
# min   -1.072256e-01 -4.464164e-02 -9.027530e-02 -1.123988e-01 -1.267807e-01
# 25%   -3.729927e-02 -4.464164e-02 -3.422907e-02 -3.665608e-02 -3.424784e-02
# 50%    5.383060e-03 -4.464164e-02 -7.283766e-03 -5.670422e-03 -4.320866e-03
# 75%    3.807591e-02  5.068012e-02  3.124802e-02  3.564379e-02  2.835801e-02
# max    1.107267e-01  5.068012e-02  1.705552e-01  1.320436e-01  1.539137e-01
#
#                  s2            s3            s4            s5            s6
# count  4.420000e+02  4.420000e+02  4.420000e+02  4.420000e+02  4.420000e+02
# mean   3.918434e-17 -5.777179e-18 -9.042540e-18  9.293722e-17  1.130318e-17
# ...

# %%
df.describe(percentiles=[0.2, 0.8])
# Out:
#                 age           sex           bmi            bp            s1  \
# count  4.420000e+02  4.420000e+02  4.420000e+02  4.420000e+02  4.420000e+02
# mean  -2.511817e-19  1.230790e-17 -2.245564e-16 -4.797570e-17 -1.381499e-17
# std    4.761905e-02  4.761905e-02  4.761905e-02  4.761905e-02  4.761905e-02
# min   -1.072256e-01 -4.464164e-02 -9.027530e-02 -1.123988e-01 -1.267807e-01
# 20%   -4.547248e-02 -4.464164e-02 -4.048038e-02 -4.009893e-02 -3.871969e-02
# 50%    5.383060e-03 -4.464164e-02 -7.283766e-03 -5.670422e-03 -4.320866e-03
# 80%    4.170844e-02  5.068012e-02  4.229559e-02  4.941519e-02  3.943444e-02
# max    1.107267e-01  5.068012e-02  1.705552e-01  1.320436e-01  1.539137e-01
#
#                  s2            s3            s4            s5            s6
# count  4.420000e+02  4.420000e+02  4.420000e+02  4.420000e+02  4.420000e+02
# mean   3.918434e-17 -5.777179e-18 -9.042540e-18  9.293722e-17  1.130318e-17
# ...

# %%
df.describe().T
# Out:
#      count          mean       std       min       25%       50%       75%  \
# age  442.0 -2.511817e-19  0.047619 -0.107226 -0.037299  0.005383  0.038076
# sex  442.0  1.230790e-17  0.047619 -0.044642 -0.044642 -0.044642  0.050680
# bmi  442.0 -2.245564e-16  0.047619 -0.090275 -0.034229 -0.007284  0.031248
# bp   442.0 -4.797570e-17  0.047619 -0.112399 -0.036656 -0.005670  0.035644
# s1   442.0 -1.381499e-17  0.047619 -0.126781 -0.034248 -0.004321  0.028358
# s2   442.0  3.918434e-17  0.047619 -0.115613 -0.030358 -0.003819  0.029844
# s3   442.0 -5.777179e-18  0.047619 -0.102307 -0.035117 -0.006584  0.029312
# s4   442.0 -9.042540e-18  0.047619 -0.076395 -0.039493 -0.002592  0.034309
# s5   442.0  9.293722e-17  0.047619 -0.126097 -0.033246 -0.001947  0.032432
# s6   442.0  1.130318e-17  0.047619 -0.137767 -0.033179 -0.001078  0.027917
#
#           max
# age  0.110727
# sex  0.050680
# bmi  0.170555
# bp   0.132044
# s1   0.153914
# s2   0.198788
# s3   0.181179
# s4   0.185234
# ...

# %% [markdown]
# ##Selection

# %%
df.columns
# Out:
# Index(['age', 'sex', 'bmi', 'bp', 's1', 's2', 's3', 's4', 's5', 's6'], dtype='object')

# %%
df['age']
# Out:
# 0      0.038076
# 1     -0.001882
# 2      0.085299
# 3     -0.089063
# 4      0.005383
#          ...
# 437    0.041708
# 438   -0.005515
# 439    0.041708
# 440   -0.045472
# 441   -0.045472
# Name: age, Length: 442, dtype: float64

# %%
type(df['age'])
# Out:
# pandas.core.series.Series

# %%
df[['age', 'sex']][:5]
# Out:
#         age       sex
# 0  0.038076  0.050680
# 1 -0.001882 -0.044642
# 2  0.085299  0.050680
# 3 -0.089063 -0.044642
# 4  0.005383 -0.044642

# %%
df[['age', 'sex']]
# Out:
#           age       sex
# 0    0.038076  0.050680
# 1   -0.001882 -0.044642
# 2    0.085299  0.050680
# 3   -0.089063 -0.044642
# 4    0.005383 -0.044642
# ..        ...       ...
# 437  0.041708  0.050680
# 438 -0.005515  0.050680
# 439  0.041708  0.050680
# 440 -0.045472 -0.044642
# 441 -0.045472 -0.044642
#
# [442 rows x 2 columns]

# %% [markdown]
# * ```.loc```
# * ```.iloc```

# %%
df.loc[0]
# Out:
# age    0.038076
# sex    0.050680
# bmi    0.061696
# bp     0.021872
# s1    -0.044223
# s2    -0.034821
# s3    -0.043401
# s4    -0.002592
# s5     0.019907
# s6    -0.017646
# Name: 0, dtype: float64

# %%
df.iloc[0]
# Out:
# age    0.038076
# sex    0.050680
# bmi    0.061696
# bp     0.021872
# s1    -0.044223
# s2    -0.034821
# s3    -0.043401
# s4    -0.002592
# s5     0.019907
# s6    -0.017646
# Name: 0, dtype: float64

# %%
df.loc[4, 'age']
# Out:
# 0.005383060374248237

# %%
df.loc[df.age < 0.005383]
# Out:
#           age       sex       bmi        bp        s1        s2        s3  \
# 1   -0.001882 -0.044642 -0.051474 -0.026328 -0.008449 -0.019163  0.074412
# 3   -0.089063 -0.044642 -0.011595 -0.036656  0.012191  0.024991 -0.036038
# 5   -0.092695 -0.044642 -0.040696 -0.019442 -0.068991 -0.079288  0.041277
# 6   -0.045472  0.050680 -0.047163 -0.015999 -0.040096 -0.024800  0.000779
# 9   -0.070900 -0.044642  0.039062 -0.033213 -0.012577 -0.034508 -0.024993
# ..        ...       ...       ...       ...       ...       ...       ...
# 435 -0.012780 -0.044642 -0.023451 -0.040099 -0.016704  0.004636 -0.017629
# 436 -0.056370 -0.044642 -0.074108 -0.050427 -0.024960 -0.047034  0.092820
# 438 -0.005515  0.050680 -0.015906 -0.067642  0.049341  0.079165 -0.028674
# 440 -0.045472 -0.044642  0.039062  0.001215  0.016318  0.015283 -0.028674
# 441 -0.045472 -0.044642 -0.073030 -0.081413  0.083740  0.027809  0.173816
#
#            s4        s5        s6
# 1   -0.039493 -0.068332 -0.092204
# ...

# %%
import numpy as np

# %%
df = pd.DataFrame(np.random.rand(9, 4), index=list("abcdefghi"), columns=list("ABCD"))

# %%
df.shape
# Out:
# (9, 4)

# %%
df.columns
# Out:
# Index(['A', 'B', 'C', 'D'], dtype='object')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 9 entries, a to i
# Data columns (total 4 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   A       9 non-null      float64
#  1   B       9 non-null      float64
#  2   C       9 non-null      float64
#  3   D       9 non-null      float64
# dtypes: float64(4)
# memory usage: 360.0+ bytes

# %%
df.head()
# Out:
#           A         B         C         D
# a  0.249184  0.055547  0.879874  0.252374
# b  0.827418  0.532244  0.484726  0.869470
# c  0.402686  0.050188  0.742329  0.322766
# d  0.060584  0.398261  0.207203  0.294927
# e  0.815209  0.630318  0.096666  0.956861

# %% [markdown]
# ##Adding a column in the dataframe

# %%
df['E'] = df['A']*100

# %%
df
# Out:
#           A         B         C         D          E
# a  0.249184  0.055547  0.879874  0.252374  24.918373
# b  0.827418  0.532244  0.484726  0.869470  82.741777
# c  0.402686  0.050188  0.742329  0.322766  40.268615
# d  0.060584  0.398261  0.207203  0.294927   6.058384
# e  0.815209  0.630318  0.096666  0.956861  81.520874
# f  0.493426  0.574082  0.550271  0.162949  49.342612
# g  0.677921  0.361444  0.726017  0.643126  67.792079
# h  0.278808  0.360635  0.761351  0.066323  27.880750
# i  0.259114  0.925265  0.288491  0.389344  25.911392

# %%
criteria = df['A'] < 0.2

# %%
df.loc[criteria, 'A'] = 0

# %%
df
# Out:
#           A         B         C         D          E
# a  0.249184  0.055547  0.879874  0.252374  24.918373
# b  0.827418  0.532244  0.484726  0.869470  82.741777
# c  0.402686  0.050188  0.742329  0.322766  40.268615
# d  0.000000  0.398261  0.207203  0.294927   6.058384
# e  0.815209  0.630318  0.096666  0.956861  81.520874
# f  0.493426  0.574082  0.550271  0.162949  49.342612
# g  0.677921  0.361444  0.726017  0.643126  67.792079
# h  0.278808  0.360635  0.761351  0.066323  27.880750
# i  0.259114  0.925265  0.288491  0.389344  25.911392

# %%
random_state = np.random.RandomState(100)
random_series = pd.Series(random_state.rand(10))

# %%
df = pd.DataFrame({'A': random_state.rand(5),
                   'B': random_state.rand(5)})

# %%
df
# Out:
#           A         B
# 0  0.891322  0.978624
# 1  0.209202  0.811683
# 2  0.185328  0.171941
# 3  0.108377  0.816225
# 4  0.219697  0.274074

# %%
df.sum()
# Out:
# A    1.613927
# B    3.052546
# dtype: float64

# %%
df.mean()
# Out:
# A    0.322785
# B    0.610509
# dtype: float64

# %% [markdown]
# #Try these operations row-wise

# %%
df.mean(axis=1)
# Out:
# 0    0.934973
# 1    0.510443
# 2    0.178635
# 3    0.462301
# 4    0.246886
# dtype: float64

# %% [markdown]
# ### Groupby
#
# Three Stages
# * Split - We split dataframe into multiple smaller dataframe based on the values of keys
# * Apply - we apply desired aggregation/ transformation on each dataframe.
# * Combine - we comine results from apply state into a dataframe

# %%
df = pd.DataFrame({'key':['A', 'B', 'C'] *2,
                   'data':range(6)})

# %%
df
# Out:
#   key  data
# 0   A     0
# 1   B     1
# 2   C     2
# 3   A     3
# 4   B     4
# 5   C     5

# %%
df.groupby("key").sum()
# Out:
#      data
# key
# A       3
# B       5
# C       7
